# %%
from tensorflow import keras
from skimage import io
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
from corrLib import readseq

# %%
img = io.imread(r'I:\Github\Python\Tracking\tracking\test_images\0000.tif')
mask = io.imread(r'I:\Github\Python\Tracking\tracking\test_images\k2.tif')
conv = signal.convolve2d(img, np.invert(mask), mode='same')
fig, ax = plt.subplots(1, 2)
ax[0].imshow(img, cmap='gray')
ax[1].imshow(conv, cmap='gray')

# %%
img.shape
# Out:
# (156, 227)

# %%
model = keras.models.Sequential([
  keras.layers.Flatten(input_shape=(156, 227)),
  keras.layers.Dense(128, activation='relu'),
  keras.layers.Dropout(0.2),
  keras.layers.Dense(30, activation='softmax')
])

# %%
l = readseq(r'I:\Github\Python\Tracking\tracking\test_images')
x_train = []
for num, i in l.iterrows():
    x_train.append(io.imread(i.Dir))
x_train = np.array(x_train)

# %%
x_train.shape
# Out:
# (50, 156, 227)

# %%
mnist = keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

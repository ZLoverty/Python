# %%
import numpy as np
from nd2reader import ND2Reader
import matplotlib.pyplot as plt
import math
import skimage.io
import pdb
from scipy import fftpack
from myImageLib import dirrec
import trackpy as tp
import os
import time
from IPython.display import clear_output, display
"""
Routine image preprocess
    - Bandpass filter (implemented, but does not perform exactly the same as 
        the ImageJ FFT bandpass command. See ImageJ source code at 
        https://imagej.nih.gov/ij/plugins/fft-filter.html)
"""
def to8bit(img16):
    # if img16.dtype != 'uint16':
        # raise ValueError('16-bit grayscale image is expected')
    max = img16.max()
    min = img16.min()
    img8 = np.floor_divide(img16 - min , (max - min + 1) / 256)
    return img8.astype('uint8')    
def bpass(img8, low, high):
    def gen_filter(img, low, high):
        filt = np.zeros(img.shape)
        h, w = img.shape
        center = [int(w/2), int(h/2)]
        Y, X = np.ogrid[:h, :w]        
        dist = ((X - center[0])**2 + (Y-center[1])**2)**.5        
        filt[(dist>low)&(dist<=high)] = 1
        return filt
    filt = gen_filter(img8, low, high)
    filt = fftpack.ifftshift(filt)
    im_fft = fftpack.fft2(img8)
    im_fft_filt = im_fft * filt
    im_new = fftpack.ifft2(im_fft_filt).real
    im_new = im_new - im_new.min()
    im_new = np.floor_divide(im_new, (im_new.max()+1)/256)
    return im_new.astype('uint8')

# %%
# J:\DNA chains\2020_06_10
if __name__ == '__main__':
    folder = r'E:\Zhengyang\10042020'
    dirList = dirrec(folder, '*.nd2')
    for nd2Dir in dirList:
        # create folder
        dir, ext = os.path.splitext(nd2Dir)
        fol, fullname = os.path.split(nd2Dir)
        name, ext = os.path.splitext(fullname)
        if os.path.exists(dir) == False:
            os.mkdir(dir)
        imgStack = []
        with ND2Reader(nd2Dir) as images:
            clear_output(wait=True)
            print('Processing ' + nd2Dir)
            for num, image in enumerate(images):
#                 if num != 153:
#                     continue
                print('Page ' + str(num))
                img8 = to8bit(image)
#                 bp = bpass(img8, 5, 100)
                skimage.io.imsave(os.path.join(dir, '{:05}.tif'.format(num)), img8)
#                 imgStack.append(img_bpass)                
#         imgStack = np.array(imgStack)
#         skimage.io.imsave(os.path.join(dir, 'processed_img_1.tif'), imgStack)
# Out:
# Processing E:\Zhengyang\10042020\00.nd2
# Page 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-a03ef0ebe805> in <module>
#      14             clear_output(wait=True)
#      15             print('Processing ' + nd2Dir)
# ---> 16             for num, image in enumerate(images):
#      17 #                 if num != 153:
#      18 #                     continue
#
# S:\Anaconda\3\lib\site-packages\slicerator\__init__.py in <genexpr>(.0)
#     225
#     226     def __iter__(self):
# --> 227         return (self._get(i) for i in self.indices)
#     228
#     229     def __len__(self):
#
# S:\Anaconda\3\lib\site-packages\slicerator\__init__.py in _get(self, key)
#     205
#     206     def _get(self, key):
# --> 207         return self._ancestor[key]
#     208
#     209     def _map_index(self, key):
#
# S:\Anaconda\3\lib\site-packages\slicerator\__init__.py in __getitem__(self, i)
#     186                 indices, new_length = key_to_indices(i, len(self))
#     187                 if new_length is None:
# --> 188                     return self._get(indices)
#     189                 else:
#     190                     return cls(self, indices, new_length, propagate_attrs)
#
# S:\Anaconda\3\lib\site-packages\pims\base_frames.py in __getitem__(self, key)
#     146         """__getitem__ is handled by Slicerator. In all pims readers, the data
#     147         returning function is get_frame."""
# --> 148         return self.get_frame(key)
#     149
#     150     def __iter__(self):
#
# S:\Anaconda\3\lib\site-packages\pims\base_frames.py in get_frame(self, i)
#     640         coords.update(**{k: v for k, v in zip(self.iter_axes, iter_coords)})
#     641
# --> 642         result = self._get_frame_wrapped(**coords)
#     643         if hasattr(result, 'metadata'):
#     644             metadata = result.metadata
#
# S:\Anaconda\3\lib\site-packages\nd2reader\reader.py in get_frame_2D(self, c, t, z, x, y, v)
#      70         y = self.metadata["height"]
#      71
# ---> 72         return self._parser.get_image_by_attributes(t, v, c, z, y, x)
#      73
#      74     @property
#
# S:\Anaconda\3\lib\site-packages\nd2reader\parser.py in get_image_by_attributes(self, frame_number, field_of_view, channel, z_level, height, width)
#     102         try:
#     103             timestamp, raw_image_data = self._get_raw_image_data(image_group_number, channel,
# --> 104                                                                  height, width)
#     105         except (TypeError):
#     106             return Frame([], frame_no=frame_number, metadata=self._get_frame_metadata())
#
# S:\Anaconda\3\lib\site-packages\nd2reader\parser.py in _get_raw_image_data(self, image_group_number, channel_offset, height, width)
#     260
#     261         """
# --> 262         chunk = self._label_map.get_image_data_location(image_group_number)
#     263         data = read_chunk(self._fh, chunk)
#     264
#
# S:\Anaconda\3\lib\site-packages\nd2reader\label_map.py in get_image_data_location(self, index)
#      78                     location = self._parse_data_location(match.end())
#      79                     self._image_data[int(match.group(1))] = location
# ---> 80         return self._image_data[index]
#      81
#      82     @property
#
# KeyError: 796

# %%
d = r'G:\DNA chains\2020_08_24\thermal_fluctuation_1.nd2'
with ND2Reader(d) as images:
#     for num, image in enumerate(images):
     images[1]
# Out:
# C:\Users\ma000301\Anaconda3\lib\site-packages\nd2reader\common_raw_metadata.py:99: RuntimeWarning: Reported average frame interval (453.3 ms) doesn't match the set interval (1000.0 ms). Using the average now.
#   warnings.warn(message % (avg_interval, interval), RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-decfcb221ba6> in <module>
#       2 with ND2Reader(d) as images:
#       3 #     for num, image in enumerate(images):
# ----> 4      images[1]
#
# ~\Anaconda3\lib\site-packages\slicerator\__init__.py in __getitem__(self, i)
#     186                 indices, new_length = key_to_indices(i, len(self))
#     187                 if new_length is None:
# --> 188                     return self._get(indices)
#     189                 else:
#     190                     return cls(self, indices, new_length, propagate_attrs)
#
# ~\Anaconda3\lib\site-packages\pims\base_frames.py in __getitem__(self, key)
#      96         """__getitem__ is handled by Slicerator. In all pims readers, the data
#      97         returning function is get_frame."""
# ---> 98         return self.get_frame(key)
#      99
#     100     def __iter__(self):
#
# ~\Anaconda3\lib\site-packages\pims\base_frames.py in get_frame(self, i)
#     590         coords.update(**{k: v for k, v in zip(self.iter_axes, iter_coords)})
#     591
# --> 592         result = self._get_frame_wrapped(**coords)
#     593         if hasattr(result, 'metadata'):
#     594             metadata = result.metadata
#
# ~\Anaconda3\lib\site-packages\nd2reader\reader.py in get_frame_2D(self, c, t, z, x, y, v)
#      70         y = self.metadata["height"]
#      71
# ---> 72         return self._parser.get_image_by_attributes(t, v, c, z, y, x)
#      73
#      74     @property
#
# ~\Anaconda3\lib\site-packages\nd2reader\parser.py in get_image_by_attributes(self, frame_number, field_of_view, channel, z_level, height, width)
#     102         try:
#     103             timestamp, raw_image_data = self._get_raw_image_data(image_group_number, channel,
# --> 104                                                                  height, width)
#     105         except (TypeError):
#     106             return Frame([], frame_no=frame_number, metadata=self._get_frame_metadata())
#
# ~\Anaconda3\lib\site-packages\nd2reader\parser.py in _get_raw_image_data(self, image_group_number, channel_offset, height, width)
#     260
#     261         """
# --> 262         chunk = self._label_map.get_image_data_location(image_group_number)
#     263         data = read_chunk(self._fh, chunk)
#     264
#
# ~\Anaconda3\lib\site-packages\nd2reader\label_map.py in get_image_data_location(self, index)
#      78                     location = self._parse_data_location(match.end())
#      79                     self._image_data[int(match.group(1))] = location
# ---> 80         return self._image_data[index]
#      81
#      82     @property
#
# KeyError: 1633

# %%
images.__doc__
# Out:
# 'PIMS wrapper for the ND2 parser.\n    This is the main class: use this to process your .nd2 files.\n    '

# %%
nd2Dir
# Out:
# 'J:\\1---drying_active_fluids\\10042020\\00.nd2'

# %%
nd2Dir = 'J:\\1---drying_active_fluids\\10042020\\07.nd2'
with ND2Reader(nd2Dir) as images:
#     for num, image in enumerate(images):
     images[1]
# Out:
# C:\Users\ma000301\Anaconda3\lib\site-packages\nd2reader\common_raw_metadata.py:99: RuntimeWarning: Reported average frame interval (828.9 ms) doesn't match the set interval (1000.0 ms). Using the average now.
#   warnings.warn(message % (avg_interval, interval), RuntimeWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f52b32427b2c> in <module>
#       2 with ND2Reader(nd2Dir) as images:
#       3 #     for num, image in enumerate(images):
# ----> 4      images[1]
#
# ~\Anaconda3\lib\site-packages\slicerator\__init__.py in __getitem__(self, i)
#     186                 indices, new_length = key_to_indices(i, len(self))
#     187                 if new_length is None:
# --> 188                     return self._get(indices)
#     189                 else:
#     190                     return cls(self, indices, new_length, propagate_attrs)
#
# ~\Anaconda3\lib\site-packages\pims\base_frames.py in __getitem__(self, key)
#      96         """__getitem__ is handled by Slicerator. In all pims readers, the data
#      97         returning function is get_frame."""
# ---> 98         return self.get_frame(key)
#      99
#     100     def __iter__(self):
#
# ~\Anaconda3\lib\site-packages\pims\base_frames.py in get_frame(self, i)
#     590         coords.update(**{k: v for k, v in zip(self.iter_axes, iter_coords)})
#     591
# --> 592         result = self._get_frame_wrapped(**coords)
#     593         if hasattr(result, 'metadata'):
#     594             metadata = result.metadata
#
# ~\Anaconda3\lib\site-packages\nd2reader\reader.py in get_frame_2D(self, c, t, z, x, y, v)
#      70         y = self.metadata["height"]
#      71
# ---> 72         return self._parser.get_image_by_attributes(t, v, c, z, y, x)
#      73
#      74     @property
#
# ~\Anaconda3\lib\site-packages\nd2reader\parser.py in get_image_by_attributes(self, frame_number, field_of_view, channel, z_level, height, width)
#     102         try:
#     103             timestamp, raw_image_data = self._get_raw_image_data(image_group_number, channel,
# --> 104                                                                  height, width)
#     105         except (TypeError):
#     106             return Frame([], frame_no=frame_number, metadata=self._get_frame_metadata())
#
# ~\Anaconda3\lib\site-packages\nd2reader\parser.py in _get_raw_image_data(self, image_group_number, channel_offset, height, width)
#     260
#     261         """
# --> 262         chunk = self._label_map.get_image_data_location(image_group_number)
#     263         data = read_chunk(self._fh, chunk)
#     264
#
# ~\Anaconda3\lib\site-packages\nd2reader\label_map.py in get_image_data_location(self, index)
#      78                     location = self._parse_data_location(match.end())
#      79                     self._image_data[int(match.group(1))] = location
# ---> 80         return self._image_data[index]
#      81
#      82     @property
#
# KeyError: 747

# %%
nd2Dir = r'D:\Data\10292019\0.nd2'
with ND2Reader(nd2Dir) as images:
    image = images[0]
plt.figure(figsize=(10,20))
plt.imshow(image, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-7ba3ff17b4bf> in <module>
#       1 nd2Dir = r'D:\Data\10292019\04.nd2'
# ----> 2 with ND2Reader(nd2Dir) as images:
#       3     image = images[0]
#       4 plt.figure(figsize=(10,20))
#       5 plt.imshow(image, cmap='gray')
#
# ~\Anaconda3\lib\site-packages\nd2reader\reader.py in __init__(self, filename)
#      19
#      20         # first use the parser to parse the file
# ---> 21         self._fh = open(filename, "rb")
#      22         self._parser = Parser(self._fh)
#      23
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Data\\10292019\\04.nd2'

# %%
bp = bpass(to8bit(image), 5, 100)
plt.figure(figsize=(10,20))
plt.imshow(bp, cmap='gray')

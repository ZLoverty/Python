# %%
import numpy as np
import matplotlib.pyplot as plt
from myImageLib import dirrec, bestcolor, bpass, wowcolor
from skimage import io, measure
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from scipy.signal import savgol_filter, medfilt
import os
from corrLib import corrS, corrI, divide_windows, distance_corr, corrIseq, readseq, match_hist
from scipy.signal import savgol_filter
from corrLib import boxsize_effect_spatial
import matplotlib as mpl
from numpy.polynomial.polynomial import polyvander
from scipy.optimize import curve_fit
from miscLib import label_slope
from corrLib import density_fluctuation
from scipy import signal
from matplotlib_scalebar.scalebar import ScaleBar
from matplotlib_scalebar.scalebar import SI_LENGTH
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.size'] = 20
matplotlib.rcParams['figure.figsize'] = 10, 6
matplotlib.rcParams['font.family'] = 'serif'

# %%
dataDir = r'E:\Google Drive\data_share\Dynamics_raw\ac_result\60\time_series.csv'
data = pd.read_csv(dataDir)

# %%
plt.plot(data.spot1)
plt.plot(data.spot2)
plt.plot(data.spot3)
plt.plot(data.spot4)
plt.plot(data.spot5)
plt.xlabel('time [frame]')
plt.ylabel('intensity')
# Out:
# Text(0, 0.5, 'intensity')

# %%
corrdataDir = r'E:\Google Drive\data_share\Dynamics_raw\ac_result\60\ac_result.csv'
acdata = pd.read_csv(corrdataDir)

# %%
plt.plot(acdata.spot1)
plt.plot(acdata.spot2)
plt.plot(acdata.spot3)
plt.plot(acdata.spot4)
plt.plot(acdata.spot5)
plt.xlabel('lag time [frame]')
plt.ylabel('autocorrelation')
# Out:
# Text(0, 0.5, 'autocorrelation')

# %%
plt.plot(acdata.mean(axis=1))

# %%
dataDir = r'E:\Google Drive\data_share\Dynamics_raw\ac_result\80_thre\time_series.csv'
data = pd.read_csv(dataDir)
corrdataDir = r'E:\Google Drive\data_share\Dynamics_raw\ac_result\80_thre\ac_result.csv'
acdata = pd.read_csv(corrdataDir)

# %%
plt.plot(data.spot1)
plt.plot(data.spot2)
plt.plot(data.spot3)
plt.plot(data.spot4)
plt.plot(data.spot5)
plt.xlabel('time [frame]')
plt.ylabel('intensity')
# Out:
# Text(0, 0.5, 'intensity')

# %%
plt.plot(acdata.spot1)
plt.plot(acdata.spot2)
plt.plot(acdata.spot3)
plt.plot(acdata.spot4)
plt.plot(acdata.spot5)
plt.xlabel('lag time [frame]')
plt.ylabel('autocorrelation')
# Out:
# Text(0, 0.5, 'autocorrelation')

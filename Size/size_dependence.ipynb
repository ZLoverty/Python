# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# %%
b = pd.read_excel(r'I:\Google Drive\Research projects\T\System_size_dependence\data.xlsx')

# %%
newcmp = ListedColormap([(1,0,0,0), (1,0,0,1)])
plt.figure(figsize=(8, 4.5))
for c in b:
    if c == 'conc':
        conc = b.conc
        continue
    plt.scatter(c*np.ones((len(conc), 1)), conc, marker='o', s=50, edgecolor='red',
            c=b[[c]], cmap=newcmp)
plt.xlabel('Gap size [$\mu$m]')
plt.ylabel('Concentration [n$_0$]')
plt.savefig('I:\Github\pd.svg', format='svg')
